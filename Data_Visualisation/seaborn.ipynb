# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data={
    'A':[1,2,3,4,5,6],
    'B':[3,4,5,6,7,8]
}
df=pd.DataFrame(data)
df
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 2  3  5
# 3  4  6
# 4  5  7
# 5  6  8

# %% [markdown]
# ***Line Plot***

# %%
plt.figure(figsize=(6,4))
sns.lineplot(x='A' , y='B' , data=df , color='red')
plt.show()

# %%
penguins_data=sns.load_dataset('penguins').head(20)
penguins_data
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 15  Adelie  Torgersen            36.6           17.8              185.0
# 16  Adelie  Torgersen            38.7           19.0              195.0
# 17  Adelie  Torgersen            42.5           20.7              197.0
# 18  Adelie  Torgersen            34.4           18.4              184.0
# 19  Adelie  Torgersen            46.0           21.5              194.0
#
#     body_mass_g     sex
# 0        3750.0    Male
# 1        3800.0  Female
# 2        3250.0  Female
# 3           NaN     NaN
# 4        3450.0  Female
# 5        3650.0    Male
# 6        3625.0  Female
# 7        4675.0    Male
# 8        3475.0     NaN
# 9        4250.0     NaN
# 10       3300.0     NaN
# 11       3700.0     NaN
# 12       3200.0  Female
# 13       3800.0    Male
# 14       4400.0    Male
# 15       3700.0  Female
# 16       3450.0  Female
# 17       4500.0    Male
# 18       3325.0  Female
# 19       4200.0    Male

# %%
sns.lineplot(x='bill_length_mm' , y='bill_depth_mm' , data=penguins_data )
plt.show()

# %%
sns.lineplot(x='bill_length_mm' , y='bill_depth_mm' , data=penguins_data , hue='sex')
plt.show()

# %%
sns.lineplot(x='bill_length_mm' , y='bill_depth_mm' , data=penguins_data , hue='sex' , size=10)
plt.show()

# %%
sns.lineplot(x='bill_length_mm' , y='bill_depth_mm' , data=penguins_data , hue='sex' , size=10 , style='sex')
plt.show()

# %%
sns.lineplot(x='bill_length_mm' , y='bill_depth_mm' , data=penguins_data , hue='sex' , size=10 , style='sex' , palette='Accent_r')
plt.show()

# %%
sns.lineplot(x='bill_length_mm' , y='bill_depth_mm' , data=penguins_data , hue='sex' , size=10 , style='sex' , palette='Accent_r' , markers=['o' , '>'])
plt.show()

# %%
sns.lineplot(x='bill_length_mm' , y='bill_depth_mm' , 
                data=penguins_data ,
                hue='sex' , size=10 , 
                style='sex' , 
                palette='Accent_r' , 
                markers=['o' , '>'] ,
                dashes=False
                )
plt.show()

# %%
sns.lineplot(x='bill_length_mm' , y='bill_depth_mm' , 
                data=penguins_data ,
                hue='sex' , size=10 , 
                style='sex' , 
                palette='Accent_r' , 
                markers=['o' , '>'] ,
                dashes=False , 
                legend='brief'
                )
plt.show()

# %%
sns.lineplot(x='bill_length_mm' , y='bill_depth_mm' , 
                data=penguins_data ,
                hue='sex' , size=10 , 
                style='sex' , 
                palette='Accent_r' , 
                markers=['o' , '>'] ,
                dashes=False , 
                legend='brief' , 
                )
plt.grid()
plt.title('This is Title')
plt.show()

# %% [markdown]
# ***Histogram***

# %%
penguins_data_2=sns.load_dataset('penguins')
penguins_data_2.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.displot(penguins_data_2['flipper_length_mm'])
plt.show()

# %%
sns.displot(penguins_data_2['flipper_length_mm'] , bins=[170,180,190,200,210,220,230] )
plt.show()

# %%
sns.displot(penguins_data_2['flipper_length_mm'] , 
            bins=[170,180,190,200,210,220,230] , 
            kde=True , 
            )
plt.show()

# %%
sns.displot(penguins_data_2['flipper_length_mm'] , 
            bins=[170,180,190,200,210,220,230] , 
            kde=True , 
            rug=True , 
            )
plt.show()

# %%
sns.displot(penguins_data_2['flipper_length_mm'] , 
            bins=[170,180,190,200,210,220,230] , 
            kde=True , 
            rug=True , 
            color='g')
plt.show()

# %%
sns.displot(penguins_data_2['flipper_length_mm'] , 
            kde=True , 
            rug=True , 
            color='g',
            log_scale=True)
plt.show()

# %% [markdown]
# ***Bar Plot***

# %%
bar_data=sns.load_dataset('penguins')

# %%
bar_data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.barplot(x='island' ,
            y='bill_length_mm' ,
            data=bar_data ,
            )
plt.show()

# %%
sns.barplot(x='island' ,
            y='bill_length_mm' ,
            data=bar_data ,
            hue='sex')
plt.show()

# %%
order_1=['Dream' , 'Biscoe' , 'Torgersen']
sns.barplot(x='island' ,
            y='bill_length_mm' ,
            data=bar_data ,
            hue='sex',
            order=order_1
            )
plt.show()

# %%
sns.barplot(x='island' ,
            y='bill_length_mm' ,
            data=bar_data ,
            hue='sex',
            hue_order=['Female','Male'])
plt.show()

# %%
sns.barplot(x='island' ,
            y='bill_length_mm' ,
            data=bar_data ,
            hue='sex',
            errorbar=('ci', False),
            edgecolor='black'
            )
plt.show()

# %%
sns.barplot(x='bill_depth_mm' ,
            y='bill_length_mm' ,
            data=bar_data ,
            hue='sex',
            errorbar=('ci', False),
            orient='h'
            )
plt.show()

# %%
sns.barplot(x='island' ,
            y='bill_length_mm' ,
            data=bar_data,
            color='g')
plt.show()

# %%
sns.barplot(x='island' ,
            y='bill_length_mm' ,
            data=bar_data ,
            hue='sex',
            errorbar=('ci', False),
            edgecolor='black',
            palette='icefire'
            )
plt.title('Bill length acc to Island' , fontsize=16)
plt.show()

# %%
sns.barplot(x='island' ,
            y='bill_length_mm' ,
            data=bar_data ,
            hue='sex',
            errorbar=('ci', False),
            edgecolor='black',
            palette='icefire',
            saturation=0.3
            )
plt.title('Bill length acc to Island' , fontsize=16)
plt.show()

# %%
sns.barplot(x='island' ,
            y='bill_length_mm' ,
            data=bar_data ,
            hue='sex',
            errorbar=('ci', 65),
            edgecolor='black',
            palette='icefire',
            errcolor='y'            )
plt.title('Bill length acc to Island' , fontsize=16)
plt.show()
# Out:
# C:\Users\progr\AppData\Local\Temp\ipykernel_12228\3677769942.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x='island' ,

# %%
sns.barplot(x='island' ,
            y='bill_length_mm' ,
            data=bar_data ,
            hue='sex',
            errorbar=('ci', 65),
            edgecolor='black',
            palette='icefire',
            errcolor='y',
            capsize=0.3            )
plt.title('Bill length acc to Island' , fontsize=16)
plt.show()
# Out:
# C:\Users\progr\AppData\Local\Temp\ipykernel_12228\2460487601.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x='island' ,

# %%
sns.barplot(x='island' ,
            y='bill_length_mm' ,
            data=bar_data ,
            hue='sex',
            errorbar=('ci', 65),
            edgecolor='black',
            palette='icefire',
            errcolor='y',
            dodge=False)
plt.title('Bill length acc to Island' , fontsize=16)
plt.show()
# Out:
# C:\Users\progr\AppData\Local\Temp\ipykernel_12228\2513001320.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x='island' ,

# %%
sns.barplot(x='island' ,
            y='bill_length_mm' ,
            data=bar_data ,
            hue='sex',
            errorbar=('ci', 65),
            edgecolor='black',
            palette='icefire',
            errcolor='y',
            alpha=0.3)
plt.title('Bill length acc to Island' , fontsize=16)
plt.show()
# Out:
# C:\Users\progr\AppData\Local\Temp\ipykernel_12228\2052732630.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x='island' ,

# %%
sns.set(style='dark')
sns.barplot(x='island' ,
            y='bill_length_mm' ,
            data=bar_data ,
            hue='sex',
            errorbar=('ci', 65),
            edgecolor='black',
            palette='icefire',
            errcolor='y')
plt.title('Bill length acc to Island' , fontsize=16)
plt.show()
# Out:
# C:\Users\progr\AppData\Local\Temp\ipykernel_12228\1594334138.py:2: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': 'y'}` instead.
#
#   sns.barplot(x='island' ,
