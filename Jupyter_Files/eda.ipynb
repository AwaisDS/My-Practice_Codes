# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:\\Users\\progr\\OneDrive\\Desktop\\data_Sets\\PSL_Season_09_dataset.csv')

# %%
df.columns
# Out:
# Index(['match_id', 'season', 'start_date', 'venue', 'innings', 'ball',
#        'batting_team', 'bowling_team', 'striker', 'non_striker', 'bowler',
#        'runs_off_bat', 'extras', 'wides', 'noballs', 'byes', 'legbyes',
#        'penalty', 'wicket_type', 'player_dismissed', 'other_wicket_type',
#        'other_player_dismissed'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# match_id                     0
# season                       0
# start_date                   0
# venue                        0
# innings                      0
# ball                         0
# batting_team                 0
# bowling_team                 0
# striker                      0
# non_striker                  0
# bowler                       0
# runs_off_bat                 0
# extras                       0
# wides                     7507
# noballs                   7772
# byes                      7779
# legbyes                   7659
# penalty                   7794
# wicket_type               7392
# player_dismissed          7392
# other_wicket_type         7795
# other_player_dismissed    7795
# dtype: int64

# %%
df.dropna(axis=1 ,inplace=True)

# %%
df.head()
# Out:
#    match_id   season  start_date                    venue  innings  ball  \
# 0   1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        1   1.5
# 1   1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        1   1.6
# 2   1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        1   2.1
# 3   1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        1   2.2
# 4   1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        1   2.3
#
#        batting_team      bowling_team           striker       non_striker  \
# 0  Lahore Qalandars  Islamabad United  Sahibzada Farhan      Fakhar Zaman
# 1  Lahore Qalandars  Islamabad United  Sahibzada Farhan      Fakhar Zaman
# 2  Lahore Qalandars  Islamabad United      Fakhar Zaman  Sahibzada Farhan
# 3  Lahore Qalandars  Islamabad United      Fakhar Zaman  Sahibzada Farhan
# 4  Lahore Qalandars  Islamabad United  Sahibzada Farhan      Fakhar Zaman
#
#         bowler  runs_off_bat  extras
# 0   Ubaid Shah             2       0
# ...

# %%
df.isnull().sum()
# Out:
# match_id        0
# season          0
# start_date      0
# venue           0
# innings         0
# ball            0
# batting_team    0
# bowling_team    0
# striker         0
# non_striker     0
# bowler          0
# runs_off_bat    0
# extras          0
# dtype: int64

# %%
df['start_date'].dtype
# Out:
# dtype('O')

# %%
lhr_vs_isl=df[(df['batting_team'] == 'Lahore Qalandars') & (df['bowling_team'] == 'Islamabad United')]

# %%
lhr_vs_isl
# Out:
#       match_id   season  start_date                       venue  innings  \
# 0      1416472  2023/24  2024-02-17     Gaddafi Stadium, Lahore        1
# 1      1416472  2023/24  2024-02-17     Gaddafi Stadium, Lahore        1
# 2      1416472  2023/24  2024-02-17     Gaddafi Stadium, Lahore        1
# 3      1416472  2023/24  2024-02-17     Gaddafi Stadium, Lahore        1
# 4      1416472  2023/24  2024-02-17     Gaddafi Stadium, Lahore        1
# ...        ...      ...         ...                         ...      ...
# 5010   1416494  2023/24  2024-03-06  Rawalpindi Cricket Stadium        1
# 5011   1416494  2023/24  2024-03-06  Rawalpindi Cricket Stadium        1
# 5012   1416494  2023/24  2024-03-06  Rawalpindi Cricket Stadium        1
# 5013   1416494  2023/24  2024-03-06  Rawalpindi Cricket Stadium        1
# 5014   1416494  2023/24  2024-03-06  Rawalpindi Cricket Stadium        1
#
#       ball      batting_team      bowling_team           striker  \
# ...

# %%
first_match=df[df['start_date'] == '2024-02-17']

# %%
first_match
# Out:
#      match_id   season  start_date                    venue  innings  ball  \
# 0     1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        1   1.5
# 1     1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        1   1.6
# 2     1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        1   2.1
# 3     1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        1   2.2
# 4     1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        1   2.3
# ..        ...      ...         ...                      ...      ...   ...
# 228   1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        2  17.6
# 229   1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        2  17.7
# 230   1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        2  17.8
# 231   1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        2  18.1
# 232   1416472  2023/24  2024-02-17  Gaddafi Stadium, Lahore        2  18.2
#
# ...

# %%
fz=first_match[first_match['striker'] == 'Fakhar Zaman']

# %%
fz['runs_off_bat'].sum()
# Out:
# 12

# %%
sns.barplot(
    x='ball',
    y='runs_off_bat',
    data=fz
)
plt.show()

# %%
first_match[(first_match['striker']== 'Fakhar Zaman') & (first_match['striker'] == 'Agha Salman')]
# Out:
# Empty DataFrame
# Columns: [match_id, season, start_date, venue, innings, ball, batting_team, bowling_team, striker, non_striker, bowler, runs_off_bat, extras]
# Index: []

# %%
sns.scatterplot(
    x='striker',
    y='runs_off_bat',
    data=first_match
)
plt.show()

# %%
sns.countplot(
    x=first_match['runs_off_bat'],
    hue=first_match['striker']
)
plt.show()
