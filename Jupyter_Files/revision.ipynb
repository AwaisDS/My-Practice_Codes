# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data={
    'Employees':['Ahmed','Awais','Ali','Abdullah','zain','Mustafa','Sonu','Esbah','Ateeqa','Madeeha'],
    'Designation':['Crew Member','Crew Member','Assistent Gel','Crew Member','Crew Trainer','Crew Trainer','Crew Member','Crew Trainer','Trainee Manager','Manager'],
    'Salary':[20000,20000,30000,20000,30000,30000,np.nan,30000,40000,80000],
    'Shift-Type':['P-T','F-T',np.nan,'P-T','F-T','F-T','P-T','F-T','P-T','F-T'],
    'Shift-Time':['6 hrs','9 hrs','9 hrs','6 hrs','9 hrs','9 hrs','6 hrs','9 hrs','6 hrs','9 hrs'],
    'Age':[30,20,21,20,24,34,22,22,np.nan,38],
    'Gender':['Male','Male','Male','Male','Male',np.nan,'male','Female','Female','Female']
}

# %%
df=pd.DataFrame(data)

# %%
df.to_csv('Employees_Data.csv',index=False)
print('data has been saved')
# Out:
# data has been saved

# %%
var=pd.read_csv('Employees_Data.csv')
var
# Out:
#   Employees      Designation   Salary Shift-Type Shift-Time   Age  Gender
# 0     Ahmed      Crew Member  20000.0        P-T      6 hrs  30.0    Male
# 1     Awais      Crew Member  20000.0        F-T      9 hrs  20.0    Male
# 2       Ali    Assistent Gel  30000.0        NaN      9 hrs  21.0    Male
# 3  Abdullah      Crew Member  20000.0        P-T      6 hrs  20.0    Male
# 4      zain     Crew Trainer  30000.0        F-T      9 hrs  24.0    Male
# 5   Mustafa     Crew Trainer  30000.0        F-T      9 hrs  34.0     NaN
# 6      Sonu      Crew Member      NaN        P-T      6 hrs  22.0    male
# 7     Esbah     Crew Trainer  30000.0        F-T      9 hrs  22.0  Female
# 8    Ateeqa  Trainee Manager  40000.0        P-T      6 hrs   NaN  Female
# 9   Madeeha          Manager  80000.0        F-T      9 hrs  38.0  Female

# %%
var.describe()
# Out:
#              Salary        Age
# count      9.000000   9.000000
# mean   33333.333333  25.666667
# std    18708.286934   6.670832
# min    20000.000000  20.000000
# 25%    20000.000000  21.000000
# 50%    30000.000000  22.000000
# 75%    30000.000000  30.000000
# max    80000.000000  38.000000

# %%
var.isnull().sum()
# Out:
# Employees      0
# Designation    0
# Salary         1
# Shift-Type     1
# Shift-Time     0
# Age            1
# Gender         1
# dtype: int64

# %%
var
# Out:
#   Employees      Designation   Salary Shift-Type Shift-Time   Age  Gender
# 0     Ahmed      Crew Member  20000.0        P-T      6 hrs  30.0    Male
# 1     Awais      Crew Member  20000.0        F-T      9 hrs  20.0    Male
# 2       Ali    Assistent Gel  30000.0        NaN      9 hrs  21.0    Male
# 3  Abdullah      Crew Member  20000.0        P-T      6 hrs  20.0    Male
# 4      zain     Crew Trainer  30000.0        F-T      9 hrs  24.0    Male
# 5   Mustafa     Crew Trainer  30000.0        F-T      9 hrs  34.0     NaN
# 6      Sonu      Crew Member      NaN        P-T      6 hrs  22.0    male
# 7     Esbah     Crew Trainer  30000.0        F-T      9 hrs  22.0  Female
# 8    Ateeqa  Trainee Manager  40000.0        P-T      6 hrs   NaN  Female
# 9   Madeeha          Manager  80000.0        F-T      9 hrs  38.0  Female

# %%
Employees_above_25=var.loc[var['Age'] > 25]
Employees_above_25
# Out:
#   Employees   Designation   Salary Shift-Type Shift-Time   Age  Gender
# 0     Ahmed   Crew Member  20000.0        P-T      6 hrs  30.0    Male
# 5   Mustafa  Crew Trainer  30000.0        F-T      9 hrs  34.0     NaN
# 9   Madeeha       Manager  80000.0        F-T      9 hrs  38.0  Female

# %%
var.loc[var['Shift-Type'] == 'P-T']
# Out:
#   Employees      Designation   Salary Shift-Type Shift-Time   Age  Gender
# 0     Ahmed      Crew Member  20000.0        P-T      6 hrs  30.0    Male
# 3  Abdullah      Crew Member  20000.0        P-T      6 hrs  20.0    Male
# 6      Sonu      Crew Member      NaN        P-T      6 hrs  22.0    male
# 8    Ateeqa  Trainee Manager  40000.0        P-T      6 hrs   NaN  Female

# %%
var['Designation']=var['Designation'].replace('Crew Member','CM')
var['Designation']=var['Designation'].replace('Trainee Manager','TM')
var['Designation']=var['Designation'].replace('Crew Trainer','CT')
var['Designation']=var['Designation'].replace('Assistent Gel','Gel')

# %%
var
# Out:
#   Employees Designation   Salary Shift-Type Shift-Time   Age  Gender
# 0     Ahmed          CM  20000.0        P-T      6 hrs  30.0    Male
# 1     Awais          CM  20000.0        F-T      9 hrs  20.0    Male
# 2       Ali         Gel  30000.0        NaN      9 hrs  21.0    Male
# 3  Abdullah          CM  20000.0        P-T      6 hrs  20.0    Male
# 4      zain          CT  30000.0        F-T      9 hrs  24.0    Male
# 5   Mustafa          CT  30000.0        F-T      9 hrs  34.0     NaN
# 6      Sonu          CM      NaN        P-T      6 hrs  22.0    male
# 7     Esbah          CT  30000.0        F-T      9 hrs  22.0  Female
# 8    Ateeqa          TM  40000.0        P-T      6 hrs   NaN  Female
# 9   Madeeha     Manager  80000.0        F-T      9 hrs  38.0  Female

# %%
var['Gender'].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Gender, dtype: bool

# %%
var['Employees'][5]
# Out:
# 'Mustafa'

# %%
var['Gender']=var['Gender'].fillna('Male')

# %%
var
# Out:
#   Employees Designation   Salary Shift-Type Shift-Time   Age  Gender
# 0     Ahmed          CM  20000.0        P-T      6 hrs  30.0    Male
# 1     Awais          CM  20000.0        F-T      9 hrs  20.0    Male
# 2       Ali         Gel  30000.0        NaN      9 hrs  21.0    Male
# 3  Abdullah          CM  20000.0        P-T      6 hrs  20.0    Male
# 4      zain          CT  30000.0        F-T      9 hrs  24.0    Male
# 5   Mustafa          CT  30000.0        F-T      9 hrs  34.0    Male
# 6      Sonu          CM      NaN        P-T      6 hrs  22.0    male
# 7     Esbah          CT  30000.0        F-T      9 hrs  22.0  Female
# 8    Ateeqa          TM  40000.0        P-T      6 hrs   NaN  Female
# 9   Madeeha     Manager  80000.0        F-T      9 hrs  38.0  Female

# %%
clear_data=var.fillna(method='ffill')
# Out:
# C:\Users\progr\AppData\Local\Temp\ipykernel_5760\4016469707.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   clear_data=var.fillna(method='ffill')

# %%
clear_data
# Out:
#   Employees Designation   Salary Shift-Type Shift-Time   Age  Gender
# 0     Ahmed          CM  20000.0        P-T      6 hrs  30.0    Male
# 1     Awais          CM  20000.0        F-T      9 hrs  20.0    Male
# 2       Ali         Gel  30000.0        F-T      9 hrs  21.0    Male
# 3  Abdullah          CM  20000.0        P-T      6 hrs  20.0    Male
# 4      zain          CT  30000.0        F-T      9 hrs  24.0    Male
# 5   Mustafa          CT  30000.0        F-T      9 hrs  34.0    Male
# 6      Sonu          CM  30000.0        P-T      6 hrs  22.0    male
# 7     Esbah          CT  30000.0        F-T      9 hrs  22.0  Female
# 8    Ateeqa          TM  40000.0        P-T      6 hrs  22.0  Female
# 9   Madeeha     Manager  80000.0        F-T      9 hrs  38.0  Female

# %%
plt.plot('Employees','Salary',data=clear_data)
plt.title('Employees Salary')
plt.xlabel('Names')
plt.ylabel('Salary')

plt.show()
